# %% [markdown]
# # Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("Hello, World! ")
# Out:
# Hello, World!

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
user_input = input('Enter a variable of your choice: ')
print(user_input)
# Out:
# abc

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here

user_num = int(input("Enter a number:"))

if user_num > 0:
    print(f"Number {user_num} is positive")
elif user_num < 0:
    print(f"Number {user_num} is negative")
else:
    print(f"Number {user_num} is 0")
# Out:
# Number 12 is positive

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here

# a=12
# b=321
# c=98

# if a > b and a >c :
#     print(f"Largest number is a: {a}")
# elif b > a and b > c:
#     print(f"Largest number is b: {b}")  
# else:
#     print(f"Largest number is c: {c}") 

#alternative approach

largest = lambda a, b, c : max(a, b, c) 
largest(12, 13, 78)
# Out:
# 78

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here

def factorial_of_num(num:int):
    if num == 0:
        return 1
    return num * factorial_of_num(num -1)

factorial_of_num(9)
# Out:
# 362880

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here

ai = 12
print(f"{ai} -- {type(ai)}")

af = 12.9
print(f"{af} -- {type(af)}")

ass= "12"
print(f"{ass} -- {type(ass)}")

ab = False
print(f"{ab} -- {type(ab)}")
# Out:
# 12 -- <class 'int'>
# 12.9 -- <class 'float'>
# 12 -- <class 'str'>
# False -- <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here

# swap_num = lambda a, b : (b, a)
# swap_num(1,2)

a = 2
b = 3

a = a+b = 5
b = a-b = 2
a = a -b = 3
# Out:
# (2, 1)

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here

#formula f = (9/5)*c + 32

c = 26

print(f"Farhenhit temp : {(9/5)*c+32:.2}")
# Out:
# Farhenhit temp : 7.9e+01

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here

a_str = "Hello"
b_str = "Python"

print(a_str + " " + b_str)
# Out:
# Hello Python

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here

a = 2
True if type(a)==int else False
# Out:
# True

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here
a = 67
b = 45

print(f"summation: {a+b}")
print(f"subtraction: {a-b}")
print(f"multiplication: {a*b}")
print(f"division: {a/b:.3f}")
# Out:
# summation: 112
# subtraction: 22
# multiplication: 3015
# division: 1.489

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here

a = 12
b = 35

print(True if a == b else False)
print(True if a != b else False)
print(True if a > b else False)
print(True if a < b else False)
# Out:
# False
# True
# False
# True

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here
a = 12
b = 9

if a == 12 and b == 9:
    print("and operation worked")
    
if  a == 12 or b != 9:
    print("or operation worked") 

print(not a )
# Out:
# and operation worked
# or operation worked
# False

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here

sqr_num = lambda x : x**2

sqr_num(6)
# Out:
# 36

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here

even_or_odd = lambda x : 'even' if x %2 == 0 else "odd"
even_or_odd(324)
# Out:
# 'even'

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here

def sum_num(num:int):
    if num == 1:
        return 1
    else:
        n = 0
        for i in range(num,0, -1):
            n = n+i
        return n    

sum_num(7)
# Out:
# 28

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here


def is_leap_year(y:int):
    if y % 400 == 0:
        return f"{y} is a leap year" 
    elif y % 100 == 0:
        return f"{y} is not a leap year" 
    elif y % 4 == 0:
         return f"{y} is a leap year" 
    else:
        return f"{y} is not a leap year"

is_leap_year(y=1996)
# Out:
# '1996 is a leap year'

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here

user_str = "palindrome"
reverse_user_str = user_str[::-1]
reverse_user_str
# Out:
# 'emordnilap'

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here

user_str = "moom"
reverse_user_str = user_str[::-1]
if reverse_user_str==user_str:
    print("str is palindrome")
else:
    print("str is not palindrome")
# Out:
# str is palindrome

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here

num_list = [17, 45, 34, 68, 54, 34]
sorted(num_list)
# Out:
# [17, 34, 34, 45, 54, 68]
