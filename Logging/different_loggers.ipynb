# %% [markdown]
# ### Logging With Multiple Loggers

# %%
import logging

logger1 = logging.getLogger("module_1")
logger1.setLevel(logging.DEBUG)

# %%
logger2 = logging.getLogger("module_2")
logger2.setLevel(logging.WARNING)

# %%
logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s-%(name)s-%(levelname)s-%(message)s',
    datefmt="%Y-%m-%d %H:%M:%S")

# %%
logger1.info("this is logger1 info message")
logger2.warning("this is logger2 info message")
# Out:
# 2026-03-09 02:02:29-module_1-INFO-this is logger1 info message
# 2026-03-09 02:02:29-module_2-WARNING-this is logger2 info message
