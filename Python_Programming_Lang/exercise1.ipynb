# %%
#Write python program to print "Hello World"

print('Hello World')
# Out:
# Hello World

# %%
#write python program that takes user input and prints it

a=input('enter input:')
print(a)
# Out:
# abc

# %%
#write a python program to check if a number is positive, negative or zero.
num = int(input('enter a number:'))
if num > 0:
    print('positive number')
elif num < 0:
    print('negative number')
else:
    print('number is 0')
# Out:
# negative number

# %%
#write python program to find largest of 3 numbers
a=19
b=89
c=78
max(a,b,c)
# Out:
# 89

# %%
#write a python program to calculate factorial of a number
number = int(input('enter a number:'))
fact=1
for num in reversed(range(number+1)):
    if num !=0:
        fact= fact * num
print(fact)
# Out:
# 120

# %%
#create variables of different data types: integer, float, string, and boolean. Print their values and types
a=1
b=3.4
c='string'
d=False
print(a,b,c,d)
print(type(a), type(b), type(c), type(d))
# Out:
# 1 3.4 string False
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'>

# %%
#write a python program to swap the values of two variables
a =1
b=2
a= a + b
b= a - b
a = a - b
print(a,b)
# Out:
# 2 1

# %%
#write program to convert celsius to fahrenheit
far = (cel * 9/5) +32

# %%
#write a python program to concatenate two strings
a ='hello'
b= 'moni'
print(a+ " "+b)
# Out:
# hello moni

# %%
#write python program to check if a variable is of specified data type.
var = 1

if isinstance(var, int):
    print('type matches')
# Out:
# type matches

# %%
#write a python program to reverse a string 
my_string = 'hello moni, cool'
for i in reversed(my_string):
    print(i, end='')
# Out:
# looc ,inom olleh

# %%
#write python program to sort list of numbers in ascending order
sorted(set([34, 12, 67, 90, 12, 78]))
# Out:
# [12, 34, 67, 78, 90]
