# %% [markdown]
# ### Access Modifiers or Access Variables
#
# * Public
# * Private
# * Protected

# %%
#examples

class Person:

    def __init__(self, name, age, gender):
        self.name = name #public - can be accessed from anywhere
        self.age = __age #private - can be accessed only inside class
        self.gender = _gender #protected - can be accessed in class and it's derived classes

class Student(Person):
    def __init__(self, name, age, gender):
        super().__init__(name, age, gender)

    def wish_student(self):
        return f"Hello {self.name}"

    def age_restict(self):
        return  f"{self.__age}"  

    def gender_reveal(self):
        return f"{self._gender}"
