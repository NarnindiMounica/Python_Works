# %% [markdown]
# ### Polymorphism

# %% [markdown]
# Polymorphism is a core concept in Object-Oriented Programming (OOPs) that allows objects of different classes to be treated as objects of a common superclass. It provides a way to perform a single action in different forms. It is achieved through method overriding and interfaces.

# %%
#Example

class Animal:

    def __init__(self):
        pass

    def speaks(self):
        return "speaks english"


class Dog(Animal):

    def speaks(self):
        return "Dog barks bow bow"

class Cat(Animal):

    def speaks(self):
        return "Cat says meow meow"               


def animal_speaks(ani_object):
    return ani_object.speaks()        

dog1= Dog()
cat1 = Cat()


animal_speaks(dog1)
# Out:
# 'Dog barks bow bow'

# %%
animal_speaks(cat1)
# Out:
# 'Cat says meow meow'

# %% [markdown]
# ### Polymorphism with Functions and Methods

# %%
#example

class Area:
    def print_area(self):
        return "Area of object"

class Circle(Area):
    def __init__(self, radius):
        self.radius = radius

    def print_area(self):
        return 3.14 * self.radius * self.radius

class Rectangle:
    def __init__(self, length, breadth):
        self.length = length
        self.breadth = breadth

    def print_area(self):
        return self.length * self.breadth


#demostration function

def area_of_shape(shape_obj):
    return shape_obj.print_area()


circle_obj = Circle(radius=5)
print(area_of_shape(shape_obj = circle_obj))

rect_obj = Rectangle(length=5, breadth=2)
print(area_of_shape(shape_obj = rect_obj))
# Out:
# 78.5
# 10
