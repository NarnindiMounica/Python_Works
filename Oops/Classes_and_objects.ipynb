# %%
#A class is a blue print for creating objects, attributes and methods.

class Car:
    pass

audi=Car()
bmw=Car()

print(type(audi))
# Out:
# <class '__main__.Car'>

# %%
print(audi)
print(bmw)

# %%
##instance variable and methods
class Dog:
    #constructor

    def __init__(self, name, age):
        self.name=name
        self.age=age

#create objects
dog1=Dog('sammy', 8)  
print(dog1.name, dog1.age)
# Out:
# sammy 8

# %%
#Defina a class with instance method
class Dog:
    def __init__(self,name, age):
        self.name=name
        self.age=age

    def bark(self):
        print(f'{self.name} says woof')

dog1=Dog('sammy', 2)
dog1.bark()
# Out:
# sammy says woof

# %%
#Modeling a bank account

#define a class for bank account

class BankAccount:
    def __init__(self, owner, bal):
        self.owner=owner
        self.bal=bal

    def deposite(self, amount):
        self.bal +=amount
        print(f'{amount} has been deposited into your account and current balance is {self.bal}')    

    def withdrawal(self, amount):
        if amount > self.bal:
            print('not enough funds to withdraw')
        else:    
            self.bal -=amount 
            print(f'{amount} has been withdrawn from your account and current balance is {self.bal}') 

    def get_balance(self):
        return self.bal         

account1=BankAccount('moni', 10000)
account1.deposite(900)         
account1.withdrawal(200)
account1.get_balance()
# Out:
# 900 has been deposited into your account and current balance is 10900
# 200 has been withdrawn from your account and current balance is 10700
# 10700

# %% [markdown]
# #### Practice questions

# %%
#create a class named 'Car' with attributes 'make', 'model' and 'year'.Create an object of the class and print its attributes.

class Car:

    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year

car1= Car('Tata', 'Nano', '2012')
print(car1.make)
print(car1.model) 
print(car1.year)
# Out:
# Tata
# Nano
# 2012

# %%
#add a method named 'start_engine' to the 'Car' class that prints a message when the engine starts. Create an object of the class and call the method.

class Car:

    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year

    def start_engine(self):
        print(f'engine of {self.model} is started..')    


car1=Car('Tata', 'Nano', 2012)
car1.start_engine()
# Out:
# engine of Nano is started..

# %%
#create a class named 'Student' with attributes 'name' and 'age'. Use a constructor to initialize these attributes. Create an object of the class and print it's attributes.

class Student:

    def __init__(self, name, age):
        self.name= name
        self.age=age


student_a=Student('moni', 12)
print(student_a.age)
# Out:
# 12

# %%
#create a class named 'BankAccount' with private attributes 'account_number' and 'balance'.Add methods to deposit and withdraw money, and check balance. Create an object of class and perform some operations.

class BankAccount:

    def __init__(self, account_number, balance):
        self.__account_number = account_number  #private attributes
        self.__balance= balance

    def deposit(self, amount):
        self.__balance += amount

    def withdraw(self, amount):
        if amount > self.__balance:
            print('not enough funds')
        else:
            self.__balance -=amount  

    def check_balance(self):
        return self.__balance    



account=BankAccount('1678900', 100)
account.deposit(10)
account.withdraw(90)
account.withdraw(30)
account.check_balance()
# Out:
# not enough funds
# 20

# %%
#Create a base class named 'Person' with attributes 'name' and 'age'. Create a derived class named 'Employee' that inherits from 'Person' and adds an attribute 'employee_id'. Create an object of the derived class and print it's attributes.

class Person:
    def __init__(self, name, age):
        self.name=name
        self.age =age

class Employee(Person):
    def __init__(self, name, age, employee_id):
        super().__init__(name, age)
        self.employee_id = employee_id


emp1=Employee('moni',28, 19008)
print(emp1.name, emp1.age, emp1.employee_id)
# Out:
# moni 28 19008

# %%
#In employee class, override the __str__ method to return a string representation of the object. Create an object of the class and print it.

class Person:
    def __init__(self, name, age):
        self.name=name
        self.age =age

class Employee(Person):
    def __init__(self, name, age, employee_id):
        super().__init__(name, age)
        self.employee_id = employee_id

    def __str__(self):
        return f'Employee name: {self.name}, with age {self.age} and employee_id is {self.employee_id}'  


emp1=Employee('moni',28, 19008)
print(emp1)
# Out:
# Employee name: moni, with age 28 and employee_id is 19008

# %%
#create a class named 'Address' with attributes 'street', 'city' and 'zipcode'. create a class named "Person" that has an 'Address' object as an attribute. create an object of the "Person" class and print it's address.

class Address:
    def __init__(self, street, city, zipcode):
        self.street = street
        self.city = city
        self.zipcode = zipcode

address1= Address('ram street', 'chennai', 603103)

class Person:
    def __init__(self, name, age, address):
        self.name=name
        self.age=age
        self.address=address

person1=Person('moni', 27, address1)
person1.address.street
# Out:
# 'ram street'

# %%
#create a class named 'Counter' with a class variable 'count'.Each time an object is created, increment the count.Add a method to get the current count. Create multiple objects and print the count.

class Counter:
    count=0
    def __init__(self):
        Counter.count += 1

    @classmethod
    def counter(cls):
        return cls.count

counter1=Counter() 
counter2=Counter()
counter3=Counter()

Counter.counter()
# Out:
# 3

# %%
#create a class named 'MathOperations' with a static method to calculate the square root of a number. Call the static method without creating an object.
import math
class MathOperations:
    @staticmethod
    def sqrt_cal(num):
        return math.sqrt(num)
    

MathOperations.sqrt_cal(9)
# Out:
# 3.0

# %%
#create a class named 'Rectangle' with private attributes 'length' and 'width'. Use properties to get and set these attributes. Create an object of the class and test the properties.

class Rectangle:

    def __init__(self, length, width):
        self.__length= length
        self.__width=width

    @property
    def length(self):
        return self.__length   

    @length.setter
    def length(self, length):
        self.__length= length

    @property
    def width(self):
        return self.__width

    @width.setter
    def width(self, width):
        self.__width = width


rect=Rectangle(10,5)
print(rect.length, rect.width)
rect.length=15
rect.width=4
print(rect.length, rect.width)
# Out:
# 10 5
# 15 4

# %%
#create an abstract base class named 'Shape' with an abstract method 'area'.Create derived classes 'Circle' and 'Square' that implement the 'area'method. Create objects of the derived classes and call the 'area' methood.
import math
from abc import ABC, abstractmethod
class Shape(ABC):

    @abstractmethod
    def area(self):
        pass

class Circle(Shape):

    def __init__(self, radius):
        self.radius=radius

    def area(self):    
        return math.pi*math.pow(self.radius,2)

class Square(Shape):

    def __init__(self, side):
        self.side=side

    def area(self):    
        return self.side**2
    

circle1= Circle(2)   
circle1.area()
# Out:
# 12.566370614359172

# %%
#create a class named 'Vector' with attributes 'x' and 'y'.Overload the '+' operator to add two 'Vector' objects. create objects of the class and test the operator overloading.

class Vector:
    
    def __init__(self, x, y):
        self.x=x
        self.y=y

    def __add__(self, other):
        return  Vector(self.x+other.x, self.y+other.y) 

    def __str__(self):
        return f'Vector({self.x }, {self.y}) ' 
    
vec1= Vector(2,3)
vec2= Vector(1,3)

print(vec1+vec2)
# Out:
# Vector(3, 6)

# %%
#create a custom exception named 'InsufficientBalanceError'. In the class 'BankAccount' class, raise this exception when a withdrawal amount is greater than the balance. Handle the exception and print an appropriate message.
class InsufficientBalanceError(Exception):
    print('not enough funds in account')

class BankAccount:

    def __init__(self, accountnum, balance):
        self.accountnum=accountnum
        self.balance=balance


    def withdraw(self, amount):
        if amount > self.balance:
            raise InsufficientBalanceError
        else:
            self.balance -=amount

    def deposit(self, amount):
        self.balance += amount

    def get_balance(self):
        return self.balance
    
baccount=BankAccount('908980', 100)
baccount.deposit(10) 
try: 
    baccount.withdraw(120)
except Exception as e:
    print(e)
# Out:
# not enough funds in account

# %%
#create a class named 'FileManager' that implements the context manager protocol to open and close a file. Use this class to read the contents of a file.

class FileManager:

    def __init__(self, filename, mode):
        self.filename=filename
        self.mode = mode

    def __enter__(self):
        self.file = open(self.filename, self.mode) 
        return self.file

    def __exit__(self, exc_type, exc_value, traceback):
        self.file.close()


file1=FileManager('D:\\Python\\data.txt', 'r')           
with file1 as file:
    contents= file.read()
    print(contents)
# Out:
# this is data file.
# it is used for reading contents of this file.

# %%
#create a class named 'Calculator' with methods to add, subtract, multiply and divide. Each method should return the object itself to allow method chaining. create an object and chain multiple method calls.

class Calculator:

    def __init__(self, value=0):
        self.value=value

    def add(self, num):
        self.value += num
        return self

    def subtract(self, num):
        self.value -= num
        return self 

    def multiply(self, num):
        self.value *= num
        return self
    
    def divide(self, num):
        try:
        
            self.value /= num
        except ZeroDivisionError as e: 
            print(e)   
        return self
    
cal = Calculator(2)
cal.add(2).subtract(3).multiply(2).divide(3)
print(cal.value)
# Out:
# 0.6666666666666666
